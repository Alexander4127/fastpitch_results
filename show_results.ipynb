# %%
from IPython.display import Audio
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generation with pitch/duration tuning

# %%
# default prediction
Audio("examples/prediction.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# double durations
Audio("examples/prediction_double_dur.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# half durations
Audio("examples/prediction_half_dur.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# pitch + 50Hz
Audio("examples/prediction_50hz_up.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# pitch - 50Hz
Audio("examples/prediction_50hz_down.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# just funny
Audio("examples/prediction_100hz_down_0.4_dur.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Training graphs

# %%
plt.gcf().set_size_inches(15, 6)

plt.subplot(1, 3, 1)
plt.imshow(Image.open("imgs/pitch_loss_and_wer.png"))

plt.subplot(1, 3, 2)
plt.imshow(Image.open("imgs/loss_and_mel_loss.png"))

plt.subplot(1, 3, 3)
plt.imshow(Image.open("imgs/dur_graphs.png"))

plt.tight_layout()
